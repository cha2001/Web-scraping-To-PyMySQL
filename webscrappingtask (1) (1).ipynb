# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
d=webdriver.Firefox()
d.get("https://www.flipkart.com/laptops/asus~brand/pr?sid=6bo,b5g")

# %%
html_content=d.page_source

# %%
html_content
# Out:
# '<html lang="en"><head><script type="text/javascript" async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=48548636561961528304247444618841662039"></script><style id="react-native-stylesheet"></style><script type="text/javascript" async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields"></script><link href="https://rukminim2.flixcart.com" rel="preconnect"><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.f9cc90.css"><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css"><link rel="stylesheet" href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.f32dbb.css"><meta http-
# ...

# %%
soup=BeautifulSoup(html_content,"html.parser")

# %%
soup
# Out:
# <html lang="en"><head><script async="async" src="https://flipkart.d1.sc.omtrdc.net/id?d_visid_ver=1.5.4&amp;callback=s_c_il%5B0%5D._setAnalyticsFields&amp;mcorgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;mid=48548636561961528304247444618841662039" type="text/javascript"></script><style id="react-native-stylesheet"></style><script async="async" src="https://dpm.demdex.net/id?d_visid_ver=1.5.4&amp;d_rtbd=json&amp;d_ver=2&amp;d_orgid=17EB401053DAF4840A490D4C%40AdobeOrg&amp;d_nsid=0&amp;d_cb=s_c_il%5B0%5D._setMarketingCloudFields" type="text/javascript"></script><link href="https://rukminim2.flixcart.com" rel="preconnect"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/atlas.chunk.f9cc90.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app_modules.chunk.c48a12.css" rel="stylesheet"/><link href="//static-assets-web.flixcart.com/fk-p-linchpin-web/fk-cp-zion/css/app.chunk.f32dbb.css" rel="stylesheet"/><meta co
# ...

# %%
cases=soup.find_all('div',class_="tUxRFH")

# %%
cases
# Out:
# [<div class="tUxRFH" data-tkid="en_66gbOUSwVsNPT3VmtucJdez41zRC6N7cx9pu4GyzRBOaMRgvzEBskGiHvrO76V80HPSYN0JXLPLxqciJ9PIXVfUFjCTyOHoHZs-Z5_PS_w0="><a class="CGtC98" href="/asus-tuf-gaming-f15-ai-powered-intel-core-i5-11th-gen-11260h-8-gb-512-gb-ssd-windows-11-home-4-graphics-nvidia-geforce-rtx-2050-144-hz-70-tgp-fx506hf-hn075w-laptop/p/itmbd858702e076f?pid=COMGS2AJESZQCMRT&amp;lid=LSTCOMGS2AJESZQCMRTZVTWT2&amp;marketplace=FLIPKART&amp;store=6bo%2Fb5g&amp;srno=b_1_1&amp;otracker=browse&amp;iid=en_66gbOUSwVsNPT3VmtucJdez41zRC6N7cx9pu4GyzRBOaMRgvzEBskGiHvrO76V80HPSYN0JXLPLxqciJ9PIXVfUFjCTyOHoHZs-Z5_PS_w0%3D&amp;ssid=0k6ze60eazzg86ps1723914986931" rel="noopener noreferrer" target="_blank"><div class="Otbq5D" data-tkid="ADVIEW_en_66gbOUSwVsNPT3VmtucJdez41zRC6N7cx9pu4GyzRBOaMRgvzEBskGiHvrO76V80HPSYN0JXLPLxqciJ9PIXVfUFjCTyOHoHZs-Z5_PS_w0="><div class="yPq5Io"><div><div class="_4WELSP" style="height: 200px; width: 200px;"><img alt="ASUS TUF Gaming F15 - AI Powered Gaming Intel Core i5 11th Gen
# ...

# %%
len(cases)
# Out:
# 24

# %%
lp_names=[]
price=[]
discount=[]
for i in cases:
    loptop=i.find('div',class_="KzDlHZ")
    lp_names.append(loptop.get_text())
    p=i.find('div',class_="Nx9bqj _4b5DiR")
    price.append(p.text)
    d=i.find('div',class_="UkUFwK")
    discount.append(d.string)
   

print(lp_names)
print(price)
print(discount)
# Out:
# ['ASUS TUF Gaming F15 - AI Powered Gaming Intel Core i5 11th Gen 11260H - (8 GB/512 GB SSD/Windows 11 Ho...', 'ASUS TUF Gaming F17 - AI Powered Gaming Intel Core i5 11th Gen 11400H - (16 GB/512 GB SSD/Windows 11 H...', 'ASUS Vivobook 15 (2024) Intel Core i3 12th Gen 1215U - (8 GB/512 GB SSD/Windows 11 Home) X1502ZA-EJ953...', 'ASUS Vivobook S 14 Intel EVO H-Series Intel Core i5 12th Gen 12500H - (16 GB/512 GB SSD/Windows 11 Hom...', 'ASUS Vivobook S14 OLED Intel EVO H-Series Intel Core i5 12th Gen 12500H - (16 GB/512 GB SSD/Windows 11...', 'ASUS Vivobook 15, with Backlit Keyboard, Intel Core i5 12th Gen 1235U - (16 GB/512 GB SSD/Windows 11 H...', 'ASUS Vivobook S15 OLED (2024) Intel EVO H-Series Intel Core i7 12th Gen 12700H - (16 GB/512 GB SSD/Win...', 'ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435HS - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVID...', 'ASUS Vivobook 14 (2023) Intel Core i3 13th Gen 1315U - (8 GB/512 GB SSD/Windows 11 Home) X1404VA-NK322...', 'ASUS Vivobook 1
# ...

# %%
import pandas as pd
df=pd.DataFrame({'laptop_name':lp_names,'price':price,'discount':discount})

# %%
df
# Out:
#                                           laptop_name    price discount
# 0   ASUS TUF Gaming F15 - AI Powered Gaming Intel ...  ₹45,990  39% off
# 1   ASUS TUF Gaming F17 - AI Powered Gaming Intel ...  ₹50,990  40% off
# 2   ASUS Vivobook 15 (2024) Intel Core i3 12th Gen...  ₹33,990  40% off
# 3   ASUS Vivobook S 14 Intel EVO H-Series Intel Co...  ₹59,990  31% off
# 4   ASUS Vivobook S14 OLED Intel EVO H-Series Inte...  ₹64,990  34% off
# 5   ASUS Vivobook 15, with Backlit Keyboard, Intel...  ₹49,990  25% off
# 6   ASUS Vivobook S15 OLED (2024) Intel EVO H-Seri...  ₹82,990  29% off
# 7   ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435...  ₹58,990  16% off
# 8   ASUS Vivobook 14 (2023) Intel Core i3 13th Gen...  ₹35,990  37% off
# 9   ASUS Vivobook 15, with Backlit Keyboard, Intel...  ₹35,990  34% off
# 10  ASUS Vivobook 16X Intel Core i5 12th Gen 12500...  ₹69,990  19% off
# 11  ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435...  ₹71,990  18% off
# ...

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
from pymysql import connect

# %%
host="localhost"
user="root"
passwd="Chandana@123"
database="mysql"

# %%
engine=create_engine("mysql+pymysql://root:Chandana%40123@localhost/mysql")

# %%
df.to_sql("laptop",con=engine,if_exists="append",index=False)
# Out:
# 24

# %%
database=connect(host='localhost',user='root',passwd='Chandana@123',database='mysql')
cur=database.cursor()
query='show tables'
cur.execute(query)
# Out:
# 39

# %%
query='select * from laptop'
cur.execute(query)
# Out:
# 48

# %%
df=pd.read_sql(query,database)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15772\1295170616.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(query,database)

# %%
df
# Out:
#                                           laptop_name      price discount
# 0   ASUS TUF Gaming F15, 90WHrs Battery Intel Core...    ₹99,990  18% off
# 1   ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435...    ₹54,990  22% off
# 2   ASUS Vivobook 15 (2024) Intel Core i3 12th Gen...    ₹33,990  40% off
# 3   ASUS Vivobook 15, with Backlit Keyboard, Intel...    ₹48,990  26% off
# 4   ASUS Vivobook Go 14 AMD Ryzen 3 Quad Core 7320...    ₹29,990  41% off
# 5   ASUS Vivobook 15, with Backlit Keyboard, Intel...    ₹34,990  36% off
# 6   ASUS Vivobook S 14 Intel EVO H-Series Intel Co...    ₹55,990  35% off
# 7   ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435...    ₹58,990  22% off
# 8   ASUS Vivobook 15 Intel Core i5 12th Gen 1235U ...    ₹43,990  37% off
# 9   ASUS TUF Gaming F17 - AI Powered Gaming Intel ...    ₹50,990  40% off
# 10  ASUS TUF Gaming F15, 90WHrs Battery Intel Core...  ₹1,06,990  18% off
# 11  ASUS TUF Gaming A15 AMD Ryzen 7 Octa Core 7435...    ₹67,990  22% off
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.histplot(df['price'], bins=10, kde=True)
plt.title('Distribution of laptop prices')
plt.xlabel('price')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\HP\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='price', order=df['price'].value_counts().index)
plt.title('Number of laptops and prices')
plt.xlabel('price')
plt.ylabel('Number of laptops')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.barh(df['laptop_name'].head(10), df['discount'].head(10), color='Red')
plt.xlabel('discount')
plt.title('Top 10 laptops and discount')
plt.gca().invert_yaxis() 
plt.show()
